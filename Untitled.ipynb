# %%
# !pip install datagovsg

# %%
import urllib.request
OneMapAuth = "token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..X7u58B6VzQ_jMlkySJ41ftQiZx3oKlxttjNWHkvspB8"
API_1 = "getPlanningareaNames?"
API_2 = "getSpokenAtHome?" 
API_3 = "getEthnicGroup?"
Location = "&planningArea=Bedok"
Year = "&year=2010"
url = "https://developers.onemap.sg/privateapi/popapi/"
url_1 = url + API_1 + OneMapAuth
url_2 = url + API_2 + OneMapAuth + Location + Year
url_3 = url + API_3 + OneMapAuth + Location + Year

print (url_1)
print (url_2)
print (url_3)

req = urllib.request.Request(url_1)
response = urllib.request.urlopen(req)
the_page = response.read()
jason = json.loads(the_page)

PlanningArea = []
for value in jason:
    mydict = dict(value)
    print(mydict['id'] + "," + mydict['pln_area_n'])
    PlanningArea.append(mydict['pln_area_n'])
# Out:
# https://developers.onemap.sg/privateapi/popapi/getPlanningareaNames?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..X7u58B6VzQ_jMlkySJ41ftQiZx3oKlxttjNWHkvspB8
# https://developers.onemap.sg/privateapi/popapi/getSpokenAtHome?token=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9..X7u58B6VzQ_jMlkySJ41ftQiZx3oKlxttjNWHkvspB8&planningArea=Bedok&year=2010
# ...
